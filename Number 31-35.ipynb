# %%
#31. GCD Calculator
#Write a Python program that computes the greatest common divisor (GCD) of two positive integers
def GCD(int1, int2):
    while int2 != 0:
        int1, int2 = int2, int1 % int2
    return int1
    
int1 = 708
int2 = 21445
print('GCD: ', GCD(int1, int2))
# Out:
# GCD:  1

# %%
def GCD(a, b):
    while b != 0:
        a, b = b, a % b
    return a

# Example usage
int1 = 708
int2 = 21
print("GCD:", GCD(int1, int2))
# Out:
# GCD: 3

# %%
def GCD(int1, int2):
    while int2 != 0:
        int1, int2 = int2, int1 % int2
    return int1   # <-- return should be outside the loop

int1 = 708
int2 = 21
print('GCD:', GCD(int1, int2))
# Out:
# GCD: 3

# %%
#32. LCM Calculator
#Write a Python program to find the least common multiple (LCM) of two positive integers.
def GCD(a, b):
    while b != 0:
        a, b = b, a % b
    return a
    
def LCM(a, b):
    return abs(a*b)//GCD(a,b)

a = 80
b = 21
print("LCM: ", LCM(a,b))
# Out:
# LCM:  1680

# %%
#33. Triple Sum with Equality Rule
#Write a Python program to sum three given integers. However, if two values are equal, the sum will be zero. 
def sumof3(a,b,c):
    if a == b or a == c or b == c:
        return 0
    else: 
        return a+b+c
 
a = 35
b = 58
c = 95
print('Sum is: ', sumof3(a,b,c))
# Out:
# Sum is:  188

# %%
#34. Conditional Sum to 20
#Write a Python program to sum two given integers. However, if the sum is between 15 and 20 it will return 20. 
def sumto20(a,b):
    if a + b in range(15,21):
        return 20
    else:
        return a + b
a = 6
b = 9
print("Conditional sum to 20 is:", sumto20(a,b))
# Out:
# Conditional sum to 20 is: 20

# %%
#35. Equality or 5 Rule Checker
#Write a Python program that returns true if the two given integer values are equal or their sum or difference is 5. 
def eq5rule(a,b):
    if a == b or a+b == 5 or abs(a-b) == 5:
        return True
    else:
        return False
a = 12
b = 30
print("Equality or 5 rule checker:", eq5rule(a,b))
# Out:
# Equality or 5 rule checker: False

# %%
def eq5rule(a, b):
    return a == b or a + b == 5 or abs(a - b) == 5
a = 12
b = 30
print("Equality or 5 rule checker:", eq5rule(a,b))
# Out:
# Equality or 5 rule checker: False
