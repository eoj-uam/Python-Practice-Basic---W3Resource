# %%
#21. Even or Odd Checker
#Write a Python program that determines whether a given number (accepted from the user) is even or odd, and prints an appropriate message to the user. 
user1 = input("enter an integer: ")
x = int(user1)
if x % 2 == 0:
    print("The number", x, "is even.")
else:
    print("The number", x, "is odd.")
# Out:
# enter an integer:  88
# The number 88 is even.

# %%
#22. Count 4 in List
#Write a Python program to count the number 4 in a given list. 
x = [3,4,6,4,66,7,4,6,99,99,4]
y = x.count(4)
print(y)
# Out:
# 4

# %%
#23. String Prefix Copies
#Write a Python program to get n (non-negative integer) copies of the first 2 characters of a given string. Return n copies of the whole string if the length is less than 2.
def string_copy(text, n):
    flen = 2
    if flen > len(text):
        flen = len(text)

    str1 = text[:flen]
    result = ''
    for i in range(n):
        result = result + str1
        
    return result
    
print(string_copy('Python', 5))
print(string_copy('P', 17))
# Out:
# PyPyPyPyPy
# PPPPPPPPPPPPPPPPP

# %%
#24. Vowel Tester
# Write a Python program to test whether a passed letter is a vowel or not. 
def is_vowel(letter):
    vowels = 'a', 'e', 'i', 'o', 'u'
    return letter in vowels
        
print(is_vowel('e'))
# Out:
# True

# %%
#25. Value in Group Tester
#Write a Python program that checks whether a specified value is contained within a group of values.
#Test Data :
#3 -> [1, 5, 8, 3] : True
#-1 -> [1, 5, 8, 3] : False

def is_present(num):
    values = [1, 5, 8, 3]
    return num in values
        
print(is_present(9))
# Out:
# False
